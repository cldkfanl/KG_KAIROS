# %%
import numpy as np
import pandas as pd

# %%
A = np.array([1,2,3])
B = np.array([4,5,6])
A+B
# Out:
# array([5, 7, 9])

# %%
A-B
# Out:
# array([-3, -3, -3])

# %%
A/B
# Out:
# array([0.25, 0.4 , 0.5 ])

# %%
df = pd.read_csv("test4.csv")

# %%
df.head()
# Out:
#    number  height
# 0       1     170
# 1       2     160
# 2       3     180
# 3       4     170
# 4       5     175

# %%
import matplotlib, matplotlib.pyplot as plt

# %%
x = df['number']
y = df['height']
plt.plot(y)
plt.show()
