# %%
# !nvidia-smi
# Out:
# Thu May  9 15:14:51 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.76                 Driver Version: 551.76         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2050      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   72C    P0             19W /   20W |    3945MiB /   4096MiB |     88%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\user

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.29 🚀 Python-3.10.11 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Setup complete ✅ (12 CPUs, 15.6 GB RAM, 370.1/475.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=yolov8s-seg.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=true
# Out:
# C:\Users\user
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# WARNING  Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at 'C:\Users\user\AppData\Roaming\Ultralytics\settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# Ultralytics YOLOv8.0.196  Python-3.10.11 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
#
# ...
#
#   0%|          | 0.00/104k [00:00<?, ?B/s]
# 100%|██████████| 104k/104k [00:00<00:00, 8.84MB/s]
# ...

# %%
# %cd {HOME}
Image(filename='runs/segment/predict/dog.jpeg', height=600)
# Out:
# C:\Users\user

# %%
# %cd 

# !pip install roboflow --quiet
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="iBxdeJKUvbnUlp2rzkBU")
project = rf.workspace("project3-edyhb").project("dressme-vqjil")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# C:\Users\user
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# C:\Users\user\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:428: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to DressME-10 in yolov8:: 100%|██████████| 4604/4604 [00:07<00:00, 629.72it/s]

# %%
from ultralytics import YOLO

# !yolo task=segment mode=train model=yolov8s-seg.pt data=C:/Users/user/Desktop/KG_kairos/ML/YOLO_v8_segmentation/first_train/DressME-2/data.yaml epochs=100 imgsz=640
# Out:
# ^C
